# %%
msg="Ahmad here !"
with open("introduction.txt","w") as file:
    file.write(msg)

# %%
with open("introduction.txt","r") as file:
    print(file.read())
# Out:
# Ahmad here !

# %%
nm = input("Enter your name : ")
age = input("Enter your age : ")
yClass = input("Enter your class : ")
with open("welcome.txt","w") as f:
    f.write(f"Welcome {nm} , Your age is {age} and you belong to {yClass} class")
