# %%
print(type(123.55))
# Out:
# <class 'float'>

# %%
print(type("123.58"))
# Out:
# <class 'str'>

# %%
print("ahmad")
print(type("ahmad"))
# Out:
# ahmad
# <class 'str'>

# %%
print(123)
print(type(123))
# Out:
# 123
# <class 'int'>

# %%
print(123.56)
print(type(123.58))
# Out:
# 123.56
# <class 'float'>

# %%
print(True)
print(type(False))
# Out:
# True
# <class 'bool'>

# %%
"A"
# Out:
# 'A'

# %%
"a"
# Out:
# 'a'

# %%
name = "Ahmad"
name2 = "Ali"

# %%
print(name, name2)
# Out:
# Ahmad Ali

# %%
Name = "Ahmad"
age  = 25
Gender ="Male"

# %%
print(Name, age, Gender)
# Out:
# Ahmad 25 Male
